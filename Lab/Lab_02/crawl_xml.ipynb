# %% [markdown]
# Import library

# %%
from lxml import etree as ET
import pandas as pd
from configparser import ConfigParser
import psycopg2
from config import config

# %%
ELEMENTS = ['article', 'inproceedings', 'proceedings', 'book', 'incollection', 'phdthesis', 'mastersthesis', 'www']

FEATURES = ['author', 'title', 'school', 'year', 'pages', 'ee', 'publisher', 'booktitle', 'address', 'journal', 'volume', 
            'number', 'month', 'url', 'cdrom', 'editor', 'cite', 'note', 'crossref', 'isbn', 'series', 'chapter', 'publnr']

# %% [markdown]
# Handle coincided features

# %%
def handle_coincided(tag, text, value):
    tag_cp = tag.copy()
    text_cp = text.copy()
    count = tag_cp.count(value)
    index = tag_cp.index(value)

    list_connect = []
    for i in range(index, index + count):
        list_connect.append(text_cp[i])
    
    list_connect = ', '.join(list_connect)
    for i in range(count - 1):
        tag_cp.remove(value)
    
    for i in range(index, index + count):
        text_cp.remove(text[i])
    
    text_cp.insert(index, list_connect)
    return tag_cp, text_cp

# %% [markdown]
# Read file XML

# %%
def getFeature(value, num_features):
    tree = ET.iterparse('./dblp.xml', dtd_validation=True, load_dtd=True)
    tags = []
    texts = []
    count = 0
    df = pd.DataFrame(columns = FEATURES)

    for _, element in tree:
        if(element.tag in FEATURES):
            tags.append(element.tag)
            texts.append(element.text)
        elif(element.tag in ELEMENTS):
            if(element.tag == value):
                try:
                    tags.append('ELM')
                    texts.append(element.tag)

                    unique = list(set(tags))
                    for i in unique:
                        if(tags.count(i) > 1):
                            tags, texts = handle_coincided(tags, texts, i)

                    arr = []
                    for i in range(len(FEATURES)):
                        if(FEATURES[i] in tags):
                            index = tags.index(FEATURES[i])
                            arr.append(texts[index])
                        else:
                            arr.append(None)
                    keys = FEATURES
                    items = arr
                    data = dict(zip(keys, items))
                    df = df.append(data, ignore_index=True)
                    count = count + 1

                except:
                    pass
                
                if(count % 1000 == 0):
                    print(count)

                if(count == num_features): 
                    break

            tags = []
            texts = []
        
        element.clear()
        while element.getprevious() is not None:
            del element.getparent()[0]  
    return df

# %%
df_final = getFeature('mastersthesis', 10000)

# %%
df_final
# Out:
#                                author  \
# 0                         Tatu Ylönen
# 1                       Peter Van Roy
# 2                        Salim Perchy
# 3              Christian Schulte 0001
# 4                     Satyan R. Coorg
# 5                Rodrigo Pastl Pontes
# 6   Salma Hosni Emam Mohamed Elmalaki
# 7                    Vanessa C. Klaas
# 8                       Kurt P. Brown
# 9                            Rita Ley
# 10               Oliver Hoffmann 0002
# 11                        Tolga Yurek
# 12                    Stephan Vollmer
#
#                                                 title  \
# 0                          Shadow Paging Is Feasible.
# 1                      A Prolog Compiler for the PLM.
# 2   Multimedia Interaction with NTCC. (Interacción...
# 3   Entwurf und Implementierung eines übersetzende...
# 4   Partitioning non-strict languages for multi-th...
# 5   Contribuições do model checking e da metodolog...
# 6   Context-Aware Runtime Engine For Android Opera...
# 7   Who's Who in the World Wide Web: Approaches to...
# 8   PRPL: A Database Workload Specification Langua...
# 9   Der Einfluss kleiner naturnaher Retentionsmaßn...
# 10  Regelbasierte Extraktion und asymmetrische Fus...
# 11     Efficient View Maintenance at Data Warehouses.
# 12  Portierung des DBLP-Systems auf ein relational...
#
#                                                school  year pages  \
# 0   Helsinki University of Technology, Department ...  1994  None
# 1                University of California at Berkeley  1984  None
# 2   Pontifical Xavierian University, Bogotá, Colombia  2013  None
# 3   Universität Karlsruhe, Institut für Logik, Kom...  1991  None
# 4   Massachusetts Institute of Technology, Cambrid...  1994  None
# 5   Instituto Tecnológico de Aeronáutica, São José...  2011  None
# 6          University of California, Los Angeles, USA  2014  None
# 7               Diplomarbeit, LMU München, Informatik  2007  None
# 8                     University of Wisconsin-Madison  1992  None
# 9   Diplomarbeit, Universität Trier, FB VI, Physis...  2006  None
# 10                                University of Trier  2009  None
# 11  University of California at Santa Barbara, Dep...  1997  None
# 12  Diplomarbeit, Universität Trier, FB IV, Inform...  2006  None
#
#                                                    ee publisher booktitle  \
# 0                                                None      None      None
# 1                                                None      None      None
# 2       https://tel.archives-ouvertes.fr/tel-01257184      None      None
# 3                                                None      None      None
# 4                  http://hdl.handle.net/1721.1/32607      None      None
# 5   http://www.bd.bibl.ita.br/tde_busca/arquivo.ph...      None      None
# 6   http://www.escholarship.org/uc/item/2f74g5mw, ...      None      None
# 7   http://www.pms.ifi.lmu.de/publikationen/diplom...      None      None
# 8                                                None      None      None
# 9   http://dblp.uni-trier.de/papers/DiplomarbeitRi...      None      None
# 10  http://dblp.uni-trier.de/papers/DiplomarbeitOl...      None      None
# 11                                               None      None      None
# 12  http://dbis.uni-trier.de/Diplomanden/Vollmer/v...      None      None
#
#    address journal  ...   url cdrom editor  cite  \
# 0     None    None  ...  None  None   None  None
# 1     None    None  ...  None  None   None  None
# 2     None    None  ...  None  None   None  None
# 3     None    None  ...  None  None   None  None
# 4     None    None  ...  None  None   None  None
# 5     None    None  ...  None  None   None  None
# 6     None    None  ...  None  None   None  None
# 7     None    None  ...  None  None   None  None
# 8     None    None  ...  None  None   None  None
# 9     None    None  ...  None  None   None  None
# 10    None    None  ...  None  None   None  None
# 11    None    None  ...  None  None   None  None
# 12    None    None  ...  None  None   None  None
#
#                                                  note crossref  isbn series  \
# 0                                                None     None  None   None
# 1                                                None     None  None   None
# 2                                                None     None  None   None
# 3                                                None     None  None   None
# 4         ndltd.org (oai:dspace.mit.edu:1721.1/32607)     None  None   None
# 5   ndltd.org (oai:agregador.ibict.br.BDTD_ITA:oai...     None  None   None
# 6                base-search.net (ftcdlib:qt2f74g5mw)     None  None   None
# 7                                                None     None  None   None
# 8                                                None     None  None   None
# 9                                                None     None  None   None
# 10  Diplomarbeit, Universität Trier, FB IV, DBIS/DBLP     None  None   None
# 11                                               None     None  None   None
# 12                                               None     None  None   None
#
#    chapter publnr
# 0     None   None
# 1     None   None
# 2     None   None
# 3     None   None
# 4     None   None
# 5     None   None
# 6     None   None
# 7     None   None
# 8     None   None
# 9     None   None
# 10    None   None
# 11    None   None
# 12    None   None
#
# [13 rows x 23 columns]

# %% [markdown]
# Save data to file csv

# %%
df_final.to_csv('mastersthesis_data.csv', index = False)

# %% [markdown]
# Save file csv to PosgreSQL

# %% [markdown]
# Connect to PostgreSQL database server and save CSV to server

# %%
def connect():
    """ Connect to the PostgreSQL database server """
    conn = None
    try:
        # connect to the PostgreSQL server
        print('Connecting to the PostgreSQL database...')

        conn = psycopg2.connect(database="DBLP",
                                user='postgres', password='duyduyduc18102001', 
                                host='localhost', port='5432'
        )
        conn.autocommit = True  

        # create a cursor
        cur = conn.cursor()
        
	    # execute a statement
        print('PostgreSQL database version:')
        cur.execute('SELECT version()')

        # display the PostgreSQL database server version
        db_version = cur.fetchone()
        print(db_version)

        sql = '''CREATE TABLE BOOK(
                author   varchar(10000),
                title   varchar(10000),
                school   varchar(10000),
                year   varchar(10000),
                pages   varchar(10000),
                ee   varchar(10000),
                publisher   varchar(10000),
                booktitle   varchar(10000),
                address   varchar(10000),
                journal   varchar(10000),
                volume   varchar(10000),
                number   varchar(10000),
                month   varchar(10000),
                url   varchar(10000),
                cdrom   varchar(10000),
                editor   varchar(10000),
                cite   varchar(10000),
                note   varchar(10000),
                crossref   varchar(10000),
                isbn   varchar(10000),
                series   varchar(10000),
                chapter   varchar(10000),
                publnr   varchar(10000));'''

        cur.execute(sql)

        sql2 = '''COPY book(
                author,
                title,
                school,
                year,
                pages,
                ee,
                publisher,
                booktitle,
                address,
                journal,
                volume,
                number,
                month,
                url,
                cdrom,
                editor,
                cite,
                note,
                crossref,
                isbn,
                series,
                chapter,
                publnr)
                FROM 'D:\\Hoc_ky_6\Tinh_Toan_Da_Phuong_Tien\\dblp\\book_data.csv'
                DELIMITER ','
                CSV HEADER;'''

        cur.execute(sql2)
        
	    # close the communication with the PostgreSQL
        cur.close()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()
            print('Database connection closed.')


if __name__ == '__main__':
    connect()
# Out:
# Connecting to the PostgreSQL database...
# PostgreSQL database version:
# ('PostgreSQL 14.2, compiled by Visual C++ build 1914, 64-bit',)
# Database connection closed.
